# %% [markdown]
# # ROS2 bag file converter

# %% [markdown]
# ## Imports and variables

# %%
import os
from pathlib import Path

from rosbags.dataframe import get_dataframe
from rosbags.highlevel import AnyReader
from rosbags.typesys import get_types_from_msg, register_types

workspace_directory='/home/hugobaptista/ros2/IMU'

# Add all topic message types to the reader's registered types
add_types = {}
for filename in os.listdir(f'{workspace_directory}/src/ccpm_msgs/msg'):
    text = Path(f'{workspace_directory}/src/ccpm_msgs/msg/{filename}').read_text()
    name=f'ccpm_msgs/msg/{filename.split(".")[0]}'
    add_types.update(get_types_from_msg(text, name))
register_types(add_types)

# %% [markdown]
# ## Convert from bag to Pandas dataframe

# %%
topics={}
dataframes={}
with AnyReader([Path(f'{workspace_directory}/IMU-rosbag_11032024')]) as reader:
    # The 'topics' dictionary's keys are the topics names and the values are their arguments (list)
    for connection in reader.connections:
        keys = []
        for field in reader.typestore.FIELDDEFS[connection.msgtype][1]:
            keys.append(field[0])
        topics[connection.topic]=keys

    # The 'dataframes' dictionary's keys are the topics names and the values are their pandas dataframe
    for topic in topics:
        dataframes[topic]=get_dataframe(reader, topic, topics.get(topic))

for topic in dataframes:
    print(f'Topic: {topic}\nDataframe:{dataframes[topic].head}\n-----------------------------------------\n')
# Out:
# There was an error in the message #39559 of /motor0/status:
#
# There was an error in the message #104212 of /motor0/status:
#
# There was an error in the message #110885 of /motor0/status:
#
# There was an error in the message #114210 of /motor0/status:
# unpack_from requires a buffer of at least 77 bytes for unpacking 1 bytes at offset 76 (actual buffer size is 76)
# There was an error in the message #134537 of /motor0/status:
# unpack_from requires a buffer of at least 77 bytes for unpacking 1 bytes at offset 76 (actual buffer size is 76)
# There was an error in the message #137086 of /motor0/status:
# unpack_from requires a buffer of at least 77 bytes for unpacking 1 bytes at offset 76 (actual buffer size is 76)
# There was an error in the message #150811 of /motor0/status:
# unpack_from requires a buffer of at least 77 bytes for unpacking 1 bytes at offset 76 (actual buffer size is 76)
# There was an error in the message #175749 of /motor0/status:
#
# There was an error in the message #184391 of /motor0/status:
#
# There was an error in the message #185741 of /motor0/status:
#
# There was an error in the message #198886 of /motor0/status:
#
# There was an error in the message #204038 of /motor0/status:
# unpack_from requires a buffer of at least 77 bytes for unpacking 1 bytes at offset 76 (actual buffer size is 76)
# There was an error in the message #205832 of /motor0/status:
#
# There was an error in the message #254128 of /motor0/status:
# unpack_from requires a buffer of at least 77 bytes for unpacking 1 bytes at offset 76 (actual buffer size is 76)
# There was an error in the message #317136 of /motor0/status:
# unpack_from requires a buffer of at least 77 bytes for unpacking 1 bytes at offset 76 (actual buffer size is 76)
# There was an error in the message #317311 of /motor0/status:
# unpack_from requires a buffer of at least 77 bytes for unpacking 1 bytes at offset 76 (actual buffer size is 76)
# There was an error in the message #355693 of /motor0/status:
#
# There was an error in the message #432193 of /motor0/status:
#
# There was an error in the message #473347 of /motor0/status:
# unpack_from requires a buffer of at least 77 bytes for unpacking 1 bytes at offset 76 (actual buffer size is 76)
# There was an error in the message #487887 of /motor0/status:
#
# There was an error in the message #489970 of /motor0/status:
#
# There was an error in the message #525201 of /motor0/status:
#
# There was an error in the message #526012 of /motor0/status:
#
# There was an error in the message #527881 of /motor0/status:
# unpack_from requires a buffer of at least 77 bytes for unpacking 1 bytes at offset 76 (actual buffer size is 76)
# There was an error in the message #530358 of /motor0/status:
#
# Topic: /motor0/status
# Dataframe:<bound method NDFrame.head of                                motor_current  motor_voltage  motor_rpm  \
# 2024-03-11 10:40:55.199897921              0        50.2500          0
# 2024-03-11 10:40:55.199911921              0        50.2500          0
# 2024-03-11 10:40:55.199919589              0        50.2500          0
# 2024-03-11 10:40:55.199928622              0        50.2500          0
# 2024-03-11 10:40:55.199936572              0        50.2500          0
# ...                                      ...            ...        ...
# 2024-03-11 10:43:52.692970706              0        49.3125          0
# 2024-03-11 10:43:52.693805297              0        49.3125          0
# 2024-03-11 10:43:52.694738292              0        49.3125          0
# 2024-03-11 10:43:52.694928581              0        49.3125          0
# 2024-03-11 10:43:52.695099759              0        49.3125          0
#
#                                torque_applied  wheel_speed  wheel_speed_mps  \
# 2024-03-11 10:40:55.199897921    5.551115e-15          0.0              0.0
# 2024-03-11 10:40:55.199911921    5.551115e-15          0.0              0.0
# 2024-03-11 10:40:55.199919589    5.551115e-15          0.0              0.0
# 2024-03-11 10:40:55.199928622    5.551115e-15          0.0              0.0
# 2024-03-11 10:40:55.199936572    5.551115e-15          0.0              0.0
# ...                                       ...          ...              ...
std_msgs__msg__Header(stamp=builtin_interfaces...
# 2024-03-11 10:40:54.944704888  std_msgs__msg__Header(stamp=builtin_interfaces...
# 2024-03-11 10:40:54.944711672  std_msgs__msg__Header(stamp=builtin_interfaces...
# 2024-03-11 10:40:54.944722244  std_msgs__msg__Header(stamp=builtin_interfaces...
# 2024-03-11 10:40:54.944729004  std_msgs__msg__Header(stamp=builtin_interfaces...
# ...                                                                          ...
# 2024-03-11 10:43:52.649312497  std_msgs__msg__Header(stamp=builtin_interfaces...
# 2024-03-11 10:43:52.662344193  std_msgs__msg__Header(stamp=builtin_interfaces...
# 2024-03-11 10:43:52.670167551  std_msgs__msg__Header(stamp=builtin_interfaces...
# 2024-03-11 10:43:52.681896392  std_msgs__msg__Header(stamp=builtin_interfaces...
# 2024-03-11 10:43:52.690621692  std_msgs__msg__Header(stamp=builtin_interfaces...
#
#                                state
# 2024-03-11 10:40:54.944686470   True
# 2024-03-11 10:40:54.944704888   True
# 2024-03-11 10:40:54.944711672   True
# 2024-03-11 10:40:54.944722244   True
# 2024-03-11 10:40:54.944729004   True
# ...                              ...
# 2024-03-11 10:43:52.649312497   True
# 2024-03-11 10:43:52.662344193   True
# 2024-03-11 10:43:52.670167551   True
# 2024-03-11 10:43:52.681896392   True
# 2024-03-11 10:43:52.690621692   True
#
# [17711 rows x 2 columns]>
# -----------------------------------------
#
# Topic: /IMU/data
# Dataframe:<bound method NDFrame.head of                                    acc_x      acc_y       acc_z     gyr_x  \
# 2024-03-11 10:40:54.932422598 -17.155067 -23.809525  975.274780  0.137329
# 2024-03-11 10:40:54.943773900 -20.390722 -32.356533  982.173462  0.064850
# 2024-03-11 10:40:55.199596539 -12.637363 -26.923079  980.952454  0.003815
# 2024-03-11 10:40:55.199878777 -12.637363 -26.923079  980.952454  0.003815
# 2024-03-11 10:40:55.199960918 -14.041514 -29.059830  981.562927  0.000000
# ...                                  ...        ...         ...       ...
# 2024-03-11 10:43:52.649130891 -15.445666 -36.324787  985.470154 -0.053406
# 2024-03-11 10:43:52.659448722  -9.157510 -38.095242  969.841309  0.026703
# 2024-03-11 10:43:52.669600876  -9.157510 -38.095242  969.841309  0.026703
# 2024-03-11 10:43:52.679831393  -7.814408 -37.118439  971.001282 -0.019073
# 2024-03-11 10:43:52.690061989  -7.814408 -37.118439  971.001282 -0.019073
#
#                                   gyr_y     gyr_z
# 2024-03-11 10:40:54.932422598 -0.057220  0.072479
# 2024-03-11 10:40:54.943773900 -0.114441 -0.129700
# 2024-03-11 10:40:55.199596539  0.003815  0.152588
# 2024-03-11 10:40:55.199878777  0.003815  0.152588
# 2024-03-11 10:40:55.199960918  0.102997  0.099182
# ...                                 ...       ...
# 2024-03-11 10:43:52.649130891 -0.213623 -0.114441
# 2024-03-11 10:43:52.659448722 -0.068665 -0.106812
# 2024-03-11 10:43:52.669600876 -0.068665 -0.106812
# 2024-03-11 10:43:52.679831393  0.034332  0.125885
# 2024-03-11 10:43:52.690061989  0.034332  0.125885
#
# [17284 rows x 6 columns]>
# -----------------------------------------

# %% [markdown]
# ## Save the Pandas dataframes as csv files

# %%
for topic in dataframes:
    dataframes[topic].to_csv(f'{workspace_directory}/csv/{topic[1:].replace("/", "_")}.csv', index=False)
    print(f'The topic {topic} was saved as {workspace_directory}/csv/{topic[1:].replace("/", "_")}.csv')
# Out:
# The topic /motor0/status was saved as /home/hugobaptista/ros2/IMU/csv/motor0_status.csv
# The topic /gps/receive was saved as /home/hugobaptista/ros2/IMU/csv/gps_receive.csv
# The topic /can_gpio/key_switch was saved as /home/hugobaptista/ros2/IMU/csv/can_gpio_key_switch.csv
# The topic /IMU/data was saved as /home/hugobaptista/ros2/IMU/csv/IMU_data.csv
